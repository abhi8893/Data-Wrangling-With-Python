# %%
import pandas as pd
import matplotlib.pyplot as plt

# ggplot style
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'


# For pandas <= 0.12
pd.set_option('display.width', 5000)
pd.set_option('display.max_columns', 60)

# %% [markdown]
# # Analyzing the bikes dataset

# %%
bikes = pd.read_csv('data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
bikes.head()
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# Date
# 2012-01-01       35                                NaN                      0             38             51       26            10       16                                  NaN
# 2012-01-02       83                                NaN                      1             68            153       53             6       43                                  NaN
# 2012-01-03      135                                NaN                      2            104            248       89             3       58                                  NaN
# 2012-01-04      144                                NaN                      1            116            318      111             8       61                                  NaN
# 2012-01-05      197                                NaN                      2            124            330       97            13       95                                  NaN

# %%
from helper import ColumnNameCleaner
col_clnr = ColumnNameCleaner(lower=True)

bikes.columns = col_clnr.clean(bikes.columns)
bikes.head()
# Out:
#             berri_1  brébeuf_(données_non_disponibles)  côte-sainte-catherine  maisonneuve_1  maisonneuve_2  du_parc  pierre-dupuy  rachel1  st-urbain_(données_non_disponibles)
# Date
# 2012-01-01       35                                NaN                      0             38             51       26            10       16                                  NaN
# 2012-01-02       83                                NaN                      1             68            153       53             6       43                                  NaN
# 2012-01-03      135                                NaN                      2            104            248       89             3       58                                  NaN
# 2012-01-04      144                                NaN                      1            116            318      111             8       61                                  NaN
# 2012-01-05      197                                NaN                      2            124            330       97            13       95                                  NaN

# %%
bikes['berri_1'].plot()

# %%
berri_bikes = bikes[['berri_1']].copy()
berri_bikes.head()
# Out:
#             berri_1
# Date
# 2012-01-01       35
# 2012-01-02       83
# 2012-01-03      135
# 2012-01-04      144
# 2012-01-05      197
